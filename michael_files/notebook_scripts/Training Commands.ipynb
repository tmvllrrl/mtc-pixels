# %% [markdown]
# ## Training Single Agent Ring Road

# %%
# %run ../../examples/train.py singleagent_ring
# Out:
# {'num_workers': 5, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.999, 'lr': 5e-05, 'train_batch_size': 60000, 'model': {'_use_default_native_models': False, 'fcnet_hiddens': [3, 3], 'fcnet_activation': 'tanh', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'num_framestacks': 'auto', 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1, 'framestack': True}, 'optimizer': {}, 'horizon': 3000, 'soft_horizon': False, 'no_done_at_end': False, 'env': None, 'observation_space': None, 'action_space': None, 'env_config': {}, 'env_task_fn': None, 'render_env': False, 'record_env': False, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, 'preprocessor_pref': 'deepmind', 'log_level': 'WARN', 'callbacks': <class 'ray.rllib.agents.callbacks.DefaultCallbacks'>, 'ignore_worker_failures': False, 'log_sys_usage': True, 'fake_sampler': False, 'framework': 'torch', 'eager_tracing': False, 'explore': True, 'exploration_config': {'type': 'StochasticSampling'}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'evaluation_parallel_to_training': False, 'in_evaluation': False, 'evaluation_config': {}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'sample_async': False, 'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 0, 'timesteps_per_iteration': 0, 'seed': None, 'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'placement_strategy': 'PACK', 'input': 'sampler', 'input_config': {}, 'actions_in_input_normalized': False, 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compress_columns': ['obs', 'new_obs'], 'output_max_file_size': 67108864, 'multiagent': {'policies': {}, 'policy_mapping_fn': None, 'policies_to_train': None, 'observation_fn': None, 'replay_mode': 'independent', 'count_steps_by': 'env_steps'}, 'logger_config': None, 'simple_optimizer': -1, 'monitor': -1, 'use_critic': True, 'use_gae': True, 'lambda': 0.97, 'kl_coeff': 0.2, 'sgd_minibatch_size': 128, 'shuffle_sequences': True, 'num_sgd_iter': 10, 'lr_schedule': None, 'vf_loss_coeff': 1.0, 'entropy_coeff': 0.0, 'entropy_coeff_schedule': None, 'clip_param': 0.3, 'vf_clip_param': 10.0, 'grad_clip': None, 'kl_target': 0.02, 'vf_share_layers': -1}
# 2023-04-12 19:12:42,797	INFO services.py:1247 -- View the Ray dashboard at http://127.0.0.1:8265
# == Status ==<br>Memory usage on this node: 5.2/31.2 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/11 CPUs, 0/11 GPUs, 0.0/9.9 GiB heap, 0.0/14.65 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/michael-lab/ray_results/singleagent_ring<br>Number of trials: 1/1 (1 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                             </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_e93a5_00000</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=6925) 2023-04-12 19:12:44,874	INFO trainer.py:720 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=6925) 2023-04-12 19:12:47,285	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 264
# (pid=6920) v_max: 5.329679917416892
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 226
# (pid=6923) v_max: 3.5232840694769565
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 246
# (pid=6922) v_max: 4.474587708995648
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 237
# (pid=6919) v_max: 4.04661795519353
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 261
# (pid=6926) v_max: 5.187261846097525
# (pid=6926) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 243
# (pid=6923) v_max: 4.331956438196479
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 264
# (pid=6922) v_max: 5.329679917416892
# (pid=6922) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 267
# (pid=6920) v_max: 5.472051563171826
# (pid=6920) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 245
# (pid=6919) v_max: 4.427046998576354
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 227
# (pid=6926) v_max: 3.570869368805752
# (pid=6926) -----------------------
# (pid=6923)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 224
# (pid=6920) v_max: 3.4281086136538996
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 250
# (pid=6923) v_max: 4.664717904914125
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 258
# (pid=6922) v_max: 5.044800727535787
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 269
# (pid=6919) v_max: 5.566938458220921
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 221
# (pid=6926) v_max: 3.285334164169417
# (pid=6926) -----------------------
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 249
# (pid=6919) v_max: 4.617190445131122
# (pid=6919) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 252
# (pid=6920) v_max: 4.759762049824181
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 257
# (pid=6923) v_max: 4.997304682316517
# (pid=6923) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 220
# (pid=6926) v_max: 3.2377399006821497
# (pid=6926) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 225
# (pid=6922) v_max: 3.4756971311168834
# (pid=6922) -----------------------
# (pid=6923)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6920) Could not connect to TraCI server at localhost:52815 [Errno 111] Connection refused
# (pid=6920)  Retrying in 2 seconds
# (pid=6923) Could not connect to TraCI server at localhost:41157 [Errno 111] Connection refused
# (pid=6923)  Retrying in 2 seconds
# (pid=6926) Could not connect to TraCI server at localhost:37495 [Errno 111] Connection refused
# (pid=6926)  Retrying in 2 seconds
# (pid=6920) Could not connect to TraCI server at localhost:52815 [Errno 111] Connection refused
# (pid=6920)  Retrying in 3 seconds
# (pid=6923) Could not connect to TraCI server at localhost:41157 [Errno 111] Connection refused
# (pid=6923)  Retrying in 3 seconds
# (pid=6926) Could not connect to TraCI server at localhost:37495 [Errno 111] Connection refused
# (pid=6926)  Retrying in 3 seconds
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 247
# (pid=6922) v_max: 4.522125250095652
# (pid=6922) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 247
# (pid=6926) v_max: 4.522125250095652
# (pid=6926) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 251
# (pid=6920) v_max: 4.71224180704279
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 263
# (pid=6923) v_max: 5.282212215151455
# (pid=6923) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 269
# (pid=6919) v_max: 5.566938458220921
# (pid=6919) -----------------------
# (pid=6922)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6922) Could not connect to TraCI server at localhost:48847 [Errno 111] Connection refused
# (pid=6922)  Retrying in 2 seconds
# (pid=6926) Could not connect to TraCI server at localhost:37495 [Errno 111] Connection refused
# (pid=6926)  Retrying in 2 seconds
# (pid=6920) Could not connect to TraCI server at localhost:52815 [Errno 111] Connection refused
# (pid=6920)  Retrying in 2 seconds
# (pid=6923) Could not connect to TraCI server at localhost:41157 [Errno 111] Connection refused
# (pid=6923)  Retrying in 2 seconds
# (pid=6919) Could not connect to TraCI server at localhost:34407 [Errno 111] Connection refused
# (pid=6919)  Retrying in 2 seconds
# (pid=6923) Could not connect to TraCI server at localhost:41157 [Errno 111] Connection refused
# (pid=6923)  Retrying in 3 seconds
# (pid=6922) Could not connect to TraCI server at localhost:48847 [Errno 111] Connection refused
# (pid=6922)  Retrying in 3 seconds
# (pid=6926) Could not connect to TraCI server at localhost:37495 [Errno 111] Connection refused
# (pid=6926)  Retrying in 3 seconds
# (pid=6920) Could not connect to TraCI server at localhost:52815 [Errno 111] Connection refused
# (pid=6920)  Retrying in 3 seconds
# (pid=6919) Could not connect to TraCI server at localhost:34407 [Errno 111] Connection refused
# (pid=6919)  Retrying in 3 seconds
# Result for PPO_WaveAttenuationPOEnv-v0_e93a5_00000:
#   agent_timesteps_total: 60000
#   custom_metrics: {}
#   date: 2023-04-12_19-14-48
#   done: false
#   episode_len_mean: 3000.0
#   episode_media: {}
#   episode_reward_max: 7059.786982337744
#   episode_reward_mean: 3115.1966644428317
#   episode_reward_min: 1521.4854427893702
#   episodes_this_iter: 20
#   episodes_total: 20
#   experiment_id: 4662df0f04464fe38c0c6093d67aa010
#   hostname: michael-lab
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.19999999999999998
#           cur_lr: 5.000000000000001e-05
#           entropy: 1.4283978670390685
#           entropy_coeff: 0.0
#           kl: 5.475637641688746e-05
#           policy_loss: -5.1614835904017565e-05
#           total_loss: 1694.4208055963902
#           vf_explained_var: 0.0017839132342487574
#           vf_loss: 1694.4208456791794
#         model: {}
#     num_agent_steps_sampled: 60000
#     num_steps_sampled: 60000
#     num_steps_trained: 60000
#   iterations_since_restore: 1
#   node_ip: 141.225.9.236
#   num_healthy_workers: 5
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 21.320114942528736
#     ram_util_percent: 21.099999999999998
#   pid: 6925
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05642635287289699
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 3.966536333973969
#     mean_inference_ms: 0.5420404378100937
#     mean_raw_obs_processing_ms: 4.313700744066923
#   time_since_restore: 121.4037389755249
#   time_this_iter_s: 121.4037389755249
#   time_total_s: 121.4037389755249
#   timers:
#     learn_throughput: 8232.467
#     learn_time_ms: 7288.216
#     sample_throughput: 525.816
#     sample_time_ms: 114108.334
#     update_time_ms: 0.978
#   timestamp: 1681344888
#   timesteps_since_restore: 0
#   timesteps_total: 60000
#   training_iteration: 1
#   trial_id: e93a5_00000
# (pid=6925) 2023-04-12 19:14:48,689	WARNING ppo.py:242 -- The magnitude of your environment rewards are more than 312.0x the scale of `vf_clip_param`. This means that it will take more than 312.0 iterations for your value function to converge. If this is not intended, consider increasing `vf_clip_param`.
# == Status ==<br>Memory usage on this node: 6.7/31.2 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 6.0/11 CPUs, 0/11 GPUs, 0.0/9.9 GiB heap, 0.0/14.65 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/michael-lab/ray_results/singleagent_ring<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                             </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_e93a5_00000</td><td>RUNNING </td><td>141.225.9.236:6925</td><td style="text-align: right;">     1</td><td style="text-align: right;">         121.404</td><td style="text-align: right;">60000</td><td style="text-align: right;">  3115.2</td><td style="text-align: right;">             7059.79</td><td style="text-align: right;">             1521.49</td><td style="text-align: right;">              3000</td></tr>
# </tbody>
# </table><br><br>
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 246
# (pid=6919) v_max: 4.474587708995648
# (pid=6919) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 231
# (pid=6920) v_max: 3.761192925277308
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 240
# (pid=6923) v_max: 4.189299083856172
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 243
# (pid=6922) v_max: 4.331956438196479
# (pid=6922) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 268
# (pid=6926) v_max: 5.5194978538368025
# (pid=6926) -----------------------
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 226
# (pid=6920) v_max: 3.5232840694769565
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 244
# (pid=6923) v_max: 4.379503211387676
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 225
# (pid=6922) v_max: 3.4756971311168834
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 222
# (pid=6919) v_max: 3.3329270738617227
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 248
# (pid=6926) v_max: 4.569659527528101
# (pid=6926) -----------------------
# (pid=6923)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 263
# (pid=6920) v_max: 5.282212215151455
# (pid=6920) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 228
# (pid=6922) v_max: 3.618452967700356
# (pid=6922) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 265
# (pid=6926) v_max: 5.37714246265477
# (pid=6926) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 228
# (pid=6923) v_max: 3.618452967700356
# (pid=6923) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 231
# (pid=6919) v_max: 3.761192925277308
# (pid=6919) -----------------------
# (pid=6926)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 267
# (pid=6922) v_max: 5.472051563171826
# (pid=6922) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 250
# (pid=6920) v_max: 4.664717904914125
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 247
# (pid=6923) v_max: 4.522125250095652
# (pid=6923) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 242
# (pid=6919) v_max: 4.2844067680020546
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 220
# (pid=6926) v_max: 3.2377399006821497
# (pid=6926) -----------------------
# (pid=6922)  Retrying in 1 seconds
# Result for PPO_WaveAttenuationPOEnv-v0_e93a5_00000:
#   agent_timesteps_total: 120000
#   custom_metrics: {}
#   date: 2023-04-12_19-16-28
#   done: false
#   episode_len_mean: 3000.0
#   episode_media: {}
#   episode_reward_max: 7820.824860800253
#   episode_reward_mean: 3304.096200151505
#   episode_reward_min: 871.4181970072441
#   episodes_this_iter: 20
#   episodes_total: 40
#   experiment_id: 4662df0f04464fe38c0c6093d67aa010
#   hostname: michael-lab
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.09999999999999999
#           cur_lr: 5.000000000000001e-05
#           entropy: 1.4288967405300914
#           entropy_coeff: 0.0
#           kl: 3.74107206981191e-05
#           policy_loss: -4.2830784219319123e-05
#           total_loss: 2082.9683123167642
#           vf_explained_var: 0.0015882286243140697
#           vf_loss: 2082.968353414637
#         model: {}
#     num_agent_steps_sampled: 120000
#     num_steps_sampled: 120000
#     num_steps_trained: 120000
#   iterations_since_restore: 2
#   node_ip: 141.225.9.236
#   num_healthy_workers: 5
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 22.085915492957753
#     ram_util_percent: 21.419014084507047
#   pid: 6925
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05620035572831221
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 3.7751495127448664
#     mean_inference_ms: 0.5412252624385419
#     mean_raw_obs_processing_ms: 4.052845974224568
#   time_since_restore: 221.1077311038971
#   time_this_iter_s: 99.70399212837219
#   time_total_s: 221.1077311038971
#   timers:
#     learn_throughput: 8093.153
#     learn_time_ms: 7413.675
#     sample_throughput: 581.772
#     sample_time_ms: 103133.156
#     update_time_ms: 0.865
#   timestamp: 1681344988
#   timesteps_since_restore: 0
#   timesteps_total: 120000
#   training_iteration: 2
#   trial_id: e93a5_00000
# (pid=6925) 2023-04-12 19:16:28,448	WARNING ppo.py:242 -- The magnitude of your environment rewards are more than 330.0x the scale of `vf_clip_param`. This means that it will take more than 330.0 iterations for your value function to converge. If this is not intended, consider increasing `vf_clip_param`.
# == Status ==<br>Memory usage on this node: 6.7/31.2 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 6.0/11 CPUs, 0/11 GPUs, 0.0/9.9 GiB heap, 0.0/14.65 GiB objects (0.0/6.0 CPU_group_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_3_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_2_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_0_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_5_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_1_27c74f409b0302333958eea1c16c481c, 0.0/1.0 accelerator_type:G, 0.0/1.0 CPU_group_4_27c74f409b0302333958eea1c16c481c)<br>Result logdir: /home/michael-lab/ray_results/singleagent_ring<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                             </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_e93a5_00000</td><td>RUNNING </td><td>141.225.9.236:6925</td><td style="text-align: right;">     2</td><td style="text-align: right;">         221.108</td><td style="text-align: right;">120000</td><td style="text-align: right;">  3304.1</td><td style="text-align: right;">             7820.82</td><td style="text-align: right;">             871.418</td><td style="text-align: right;">              3000</td></tr>
# </tbody>
# </table><br><br>
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 263
# (pid=6920) v_max: 5.282212215151455
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 247
# (pid=6923) v_max: 4.522125250095652
# (pid=6923) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 259
# (pid=6919) v_max: 5.092292348291853
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 229
# (pid=6926) v_max: 3.666034803266416
# (pid=6926) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 260
# (pid=6922) v_max: 5.139779427502188
# (pid=6922) -----------------------
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 267
# (pid=6920) v_max: 5.472051563171826
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 243
# (pid=6923) v_max: 4.331956438196479
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 268
# (pid=6922) v_max: 5.5194978538368025
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 227
# (pid=6919) v_max: 3.570869368805752
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 259
# (pid=6926) v_max: 5.092292348291853
# (pid=6926) -----------------------
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 266
# (pid=6922) v_max: 5.42459972166245
# (pid=6922) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 263
# (pid=6923) v_max: 5.282212215151455
# (pid=6923) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 260
# (pid=6919) v_max: 5.139779427502188
# (pid=6919) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 263
# (pid=6920) v_max: 5.282212215151455
# (pid=6920) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 226
# (pid=6926) v_max: 3.5232840694769565
# (pid=6926) -----------------------
# (pid=6923)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 261
# (pid=6923) v_max: 5.187261846097525
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 270
# (pid=6922) v_max: 5.6143732387852054
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 250
# (pid=6919) v_max: 4.664717904914125
# (pid=6919) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 224
# (pid=6920) v_max: 3.4281086136538996
# (pid=6920) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 233
# (pid=6926) v_max: 3.856343201216534
# (pid=6926) -----------------------
# (pid=6923)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# Result for PPO_WaveAttenuationPOEnv-v0_e93a5_00000:
#   agent_timesteps_total: 180000
#   custom_metrics: {}
#   date: 2023-04-12_19-18-06
#   done: false
#   episode_len_mean: 3000.0
#   episode_media: {}
#   episode_reward_max: 9183.91592368554
#   episode_reward_mean: 3216.840774964882
#   episode_reward_min: 567.8324035745178
#   episodes_this_iter: 20
#   episodes_total: 60
#   experiment_id: 4662df0f04464fe38c0c6093d67aa010
#   hostname: michael-lab
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.049999999999999996
#           cur_lr: 5.000000000000001e-05
#           entropy: 1.4165568458246016
#           entropy_coeff: 0.0
#           kl: 0.0010310730898686607
#           policy_loss: -0.0006497127271704385
#           total_loss: 1859.2899197771605
#           vf_explained_var: -0.0002741440257523209
#           vf_loss: 1859.2905157874134
#         model: {}
#     num_agent_steps_sampled: 180000
#     num_steps_sampled: 180000
#     num_steps_trained: 180000
#   iterations_since_restore: 3
#   node_ip: 141.225.9.236
#   num_healthy_workers: 5
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 21.966428571428573
#     ram_util_percent: 21.400000000000002
#   pid: 6925
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.0559958122048764
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 3.6685580934480915
#     mean_inference_ms: 0.5393301243465446
#     mean_raw_obs_processing_ms: 3.903140312438574
#   time_since_restore: 319.30235838890076
#   time_this_iter_s: 98.19462728500366
#   time_total_s: 319.30235838890076
#   timers:
#     learn_throughput: 8044.386
#     learn_time_ms: 7458.618
#     sample_throughput: 606.253
#     sample_time_ms: 98968.551
#     update_time_ms: 0.824
#   timestamp: 1681345086
#   timesteps_since_restore: 0
#   timesteps_total: 180000
#   training_iteration: 3
#   trial_id: e93a5_00000
# == Status ==<br>Memory usage on this node: 6.7/31.2 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 6.0/11 CPUs, 0/11 GPUs, 0.0/9.9 GiB heap, 0.0/14.65 GiB objects (0.0/6.0 CPU_group_27c74f409b0302333958eea1c16c481c, 0.0/1.0 accelerator_type:G, 0.0/1.0 CPU_group_2_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_0_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_5_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_4_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_1_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_3_27c74f409b0302333958eea1c16c481c)<br>Result logdir: /home/michael-lab/ray_results/singleagent_ring<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                             </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_e93a5_00000</td><td>RUNNING </td><td>141.225.9.236:6925</td><td style="text-align: right;">     3</td><td style="text-align: right;">         319.302</td><td style="text-align: right;">180000</td><td style="text-align: right;"> 3216.84</td><td style="text-align: right;">             9183.92</td><td style="text-align: right;">             567.832</td><td style="text-align: right;">              3000</td></tr>
# </tbody>
# </table><br><br>
# (pid=6925) 2023-04-12 19:18:06,689	WARNING ppo.py:242 -- The magnitude of your environment rewards are more than 322.0x the scale of `vf_clip_param`. This means that it will take more than 322.0 iterations for your value function to converge. If this is not intended, consider increasing `vf_clip_param`.
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 246
# (pid=6920) v_max: 4.474587708995648
# (pid=6920) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 240
# (pid=6922) v_max: 4.189299083856172
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 230
# (pid=6919) v_max: 3.7136148111012934
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 247
# (pid=6926) v_max: 4.522125250095652
# (pid=6926) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 225
# (pid=6923) v_max: 3.4756971311168834
# (pid=6923) -----------------------
# (pid=6920)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 270
# (pid=6922) v_max: 5.6143732387852054
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 234
# (pid=6919) v_max: 3.903915223349057
# (pid=6919) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 252
# (pid=6920) v_max: 4.759762049824181
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 242
# (pid=6923) v_max: 4.2844067680020546
# (pid=6923) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 257
# (pid=6926) v_max: 4.997304682316517
# (pid=6926) -----------------------
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 242
# (pid=6919) v_max: 4.2844067680020546
# (pid=6919) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 270
# (pid=6920) v_max: 5.6143732387852054
# (pid=6920) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 228
# (pid=6922) v_max: 3.618452967700356
# (pid=6922) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 237
# (pid=6926) v_max: 4.04661795519353
# (pid=6926) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 248
# (pid=6923) v_max: 4.569659527528101
# (pid=6923) -----------------------
# (pid=6919)  Retrying in 1 seconds
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 267
# (pid=6920) v_max: 5.472051563171826
# (pid=6920) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 221
# (pid=6922) v_max: 3.285334164169417
# (pid=6922) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 228
# (pid=6926) v_max: 3.618452967700356
# (pid=6926) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 269
# (pid=6923) v_max: 5.566938458220921
# (pid=6923) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 242
# (pid=6919) v_max: 4.2844067680020546
# (pid=6919) -----------------------
# (pid=6922)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# Result for PPO_WaveAttenuationPOEnv-v0_e93a5_00000:
#   agent_timesteps_total: 240000
#   custom_metrics: {}
#   date: 2023-04-12_19-19-44
#   done: false
#   episode_len_mean: 3000.0
#   episode_media: {}
#   episode_reward_max: 9266.4311862913
#   episode_reward_mean: 3894.97080325965
#   episode_reward_min: 567.8324035745178
#   episodes_this_iter: 20
#   episodes_total: 80
#   experiment_id: 4662df0f04464fe38c0c6093d67aa010
#   hostname: michael-lab
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.024999999999999998
#           cur_lr: 5.000000000000001e-05
#           entropy: 1.403260450602086
#           entropy_coeff: 0.0
#           kl: 8.008571544620002e-05
#           policy_loss: -6.0822569461328896e-05
#           total_loss: 4465.098664930787
#           vf_explained_var: 0.0002722953795455396
#           vf_loss: 4465.098727189249
#         model: {}
#     num_agent_steps_sampled: 240000
#     num_steps_sampled: 240000
#     num_steps_trained: 240000
#   iterations_since_restore: 4
#   node_ip: 141.225.9.236
#   num_healthy_workers: 5
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 22.22142857142857
#     ram_util_percent: 21.404285714285717
#   pid: 6925
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05585997468227601
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 3.601630027520778
#     mean_inference_ms: 0.5382237654676066
#     mean_raw_obs_processing_ms: 3.8027711860347653
#   time_since_restore: 417.4042344093323
#   time_this_iter_s: 98.10187602043152
#   time_total_s: 417.4042344093323
#   timers:
#     learn_throughput: 7939.268
#     learn_time_ms: 7557.372
#     sample_throughput: 619.922
#     sample_time_ms: 96786.341
#     update_time_ms: 0.9
#   timestamp: 1681345184
#   timesteps_since_restore: 0
#   timesteps_total: 240000
#   training_iteration: 4
#   trial_id: e93a5_00000
# == Status ==<br>Memory usage on this node: 6.7/31.2 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 6.0/11 CPUs, 0/11 GPUs, 0.0/9.9 GiB heap, 0.0/14.65 GiB objects (0.0/1.0 CPU_group_0_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_1_27c74f409b0302333958eea1c16c481c, 0.0/1.0 accelerator_type:G, 0.0/6.0 CPU_group_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_4_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_2_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_5_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_3_27c74f409b0302333958eea1c16c481c)<br>Result logdir: /home/michael-lab/ray_results/singleagent_ring<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                             </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_e93a5_00000</td><td>RUNNING </td><td>141.225.9.236:6925</td><td style="text-align: right;">     4</td><td style="text-align: right;">         417.404</td><td style="text-align: right;">240000</td><td style="text-align: right;"> 3894.97</td><td style="text-align: right;">             9266.43</td><td style="text-align: right;">             567.832</td><td style="text-align: right;">              3000</td></tr>
# </tbody>
# </table><br><br>
# (pid=6925) 2023-04-12 19:19:44,812	WARNING ppo.py:242 -- The magnitude of your environment rewards are more than 389.0x the scale of `vf_clip_param`. This means that it will take more than 389.0 iterations for your value function to converge. If this is not intended, consider increasing `vf_clip_param`.
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 222
# (pid=6922) v_max: 3.3329270738617227
# (pid=6922) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 247
# (pid=6923) v_max: 4.522125250095652
# (pid=6923) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 255
# (pid=6919) v_max: 4.902299776966978
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 223
# (pid=6926) v_max: 3.3805185755587788
# (pid=6926) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 264
# (pid=6920) v_max: 5.329679917416892
# (pid=6920) -----------------------
# (pid=6923)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6922) Could not connect to TraCI server at localhost:48847 [Errno 111] Connection refused
# (pid=6922)  Retrying in 2 seconds
# (pid=6919) Could not connect to TraCI server at localhost:34407 [Errno 111] Connection refused
# (pid=6919)  Retrying in 2 seconds
# (pid=6922) Could not connect to TraCI server at localhost:48847 [Errno 111] Connection refused
# (pid=6922)  Retrying in 3 seconds
# (pid=6919) Could not connect to TraCI server at localhost:34407 [Errno 111] Connection refused
# (pid=6919)  Retrying in 3 seconds
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 267
# (pid=6920) v_max: 5.472051563171826
# (pid=6920) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 255
# (pid=6919) v_max: 4.902299776966978
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 230
# (pid=6926) v_max: 3.7136148111012934
# (pid=6926) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 229
# (pid=6923) v_max: 3.666034803266416
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 223
# (pid=6922) v_max: 3.3805185755587788
# (pid=6922) -----------------------
# (pid=6926)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 268
# (pid=6922) v_max: 5.5194978538368025
# (pid=6922) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 221
# (pid=6923) v_max: 3.285334164169417
# (pid=6923) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 261
# (pid=6919) v_max: 5.187261846097525
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 240
# (pid=6926) v_max: 4.189299083856172
# (pid=6926) -----------------------
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 254
# (pid=6920) v_max: 4.854791141191876
# (pid=6920) -----------------------
# (pid=6923)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 241
# (pid=6920) v_max: 4.236854288051661
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 222
# (pid=6923) v_max: 3.3329270738617227
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 230
# (pid=6922) v_max: 3.7136148111012934
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 235
# (pid=6919) v_max: 3.9514850725282584
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 232
# (pid=6926) v_max: 3.8087690783250063
# (pid=6926) -----------------------
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# Result for PPO_WaveAttenuationPOEnv-v0_e93a5_00000:
#   agent_timesteps_total: 300000
#   custom_metrics: {}
#   date: 2023-04-12_19-21-29
#   done: false
#   episode_len_mean: 3000.0
#   episode_media: {}
#   episode_reward_max: 10362.342470896701
#   episode_reward_mean: 4326.300239988919
#   episode_reward_min: 567.8324035745178
#   episodes_this_iter: 20
#   episodes_total: 100
#   experiment_id: 4662df0f04464fe38c0c6093d67aa010
#   hostname: michael-lab
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 0.012499999999999999
#           cur_lr: 5.000000000000001e-05
#           entropy: 1.378004807068595
#           entropy_coeff: 0.0
#           kl: 0.0006144984125194701
#           policy_loss: -0.0002660789970816897
#           total_loss: 4710.00487458772
#           vf_explained_var: 0.0003969347453676164
#           vf_loss: 4710.005133147738
#         model: {}
#     num_agent_steps_sampled: 300000
#     num_steps_sampled: 300000
#     num_steps_trained: 300000
#   iterations_since_restore: 5
#   node_ip: 141.225.9.236
#   num_healthy_workers: 5
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 20.77133333333333
#     ram_util_percent: 21.294000000000008
#   pid: 6925
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05576437868358509
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 3.555467531199938
#     mean_inference_ms: 0.5373525538218361
#     mean_raw_obs_processing_ms: 3.7523335313612405
#   time_since_restore: 522.5320196151733
#   time_this_iter_s: 105.12778520584106
#   time_total_s: 522.5320196151733
#   timers:
#     learn_throughput: 7875.491
#     learn_time_ms: 7618.573
#     sample_throughput: 619.319
#     sample_time_ms: 96880.578
#     update_time_ms: 0.902
#   timestamp: 1681345289
#   timesteps_since_restore: 0
#   timesteps_total: 300000
#   training_iteration: 5
#   trial_id: e93a5_00000
# == Status ==<br>Memory usage on this node: 6.7/31.2 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 6.0/11 CPUs, 0/11 GPUs, 0.0/9.9 GiB heap, 0.0/14.65 GiB objects (0.0/1.0 CPU_group_5_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_3_27c74f409b0302333958eea1c16c481c, 0.0/1.0 accelerator_type:G, 0.0/1.0 CPU_group_2_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_4_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_0_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_1_27c74f409b0302333958eea1c16c481c, 0.0/6.0 CPU_group_27c74f409b0302333958eea1c16c481c)<br>Result logdir: /home/michael-lab/ray_results/singleagent_ring<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                             </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_e93a5_00000</td><td>RUNNING </td><td>141.225.9.236:6925</td><td style="text-align: right;">     5</td><td style="text-align: right;">         522.532</td><td style="text-align: right;">300000</td><td style="text-align: right;">  4326.3</td><td style="text-align: right;">             10362.3</td><td style="text-align: right;">             567.832</td><td style="text-align: right;">              3000</td></tr>
# </tbody>
# </table><br><br>
# (pid=6925) 2023-04-12 19:21:29,965	WARNING ppo.py:242 -- The magnitude of your environment rewards are more than 433.0x the scale of `vf_clip_param`. This means that it will take more than 433.0 iterations for your value function to converge. If this is not intended, consider increasing `vf_clip_param`.
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 255
# (pid=6920) v_max: 4.902299776966978
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 258
# (pid=6923) v_max: 5.044800727535787
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 235
# (pid=6922) v_max: 3.9514850725282584
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 262
# (pid=6919) v_max: 5.234739483008334
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 255
# (pid=6926) v_max: 4.902299776966978
# (pid=6926) -----------------------
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6920) Could not connect to TraCI server at localhost:52815 [Errno 111] Connection refused
# (pid=6920)  Retrying in 2 seconds
# (pid=6923) Could not connect to TraCI server at localhost:41157 [Errno 111] Connection refused
# (pid=6923)  Retrying in 2 seconds
# (pid=6922) Could not connect to TraCI server at localhost:48847 [Errno 111] Connection refused
# (pid=6922)  Retrying in 2 seconds
# (pid=6919) Could not connect to TraCI server at localhost:34407 [Errno 111] Connection refused
# (pid=6919)  Retrying in 2 seconds
# (pid=6926) Could not connect to TraCI server at localhost:37495 [Errno 111] Connection refused
# (pid=6926)  Retrying in 2 seconds
# (pid=6920) Could not connect to TraCI server at localhost:52815 [Errno 111] Connection refused
# (pid=6920)  Retrying in 3 seconds
# (pid=6923) Could not connect to TraCI server at localhost:41157 [Errno 111] Connection refused
# (pid=6923)  Retrying in 3 seconds
# (pid=6922) Could not connect to TraCI server at localhost:48847 [Errno 111] Connection refused
# (pid=6922)  Retrying in 3 seconds
# (pid=6919) Could not connect to TraCI server at localhost:34407 [Errno 111] Connection refused
# (pid=6919)  Retrying in 3 seconds
# (pid=6926) Could not connect to TraCI server at localhost:37495 [Errno 111] Connection refused
# (pid=6926)  Retrying in 3 seconds
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6920)
# (pid=6920) -----------------------
# (pid=6920) ring length: 258
# (pid=6920) v_max: 5.044800727535787
# (pid=6920) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 255
# (pid=6923) v_max: 4.902299776966978
# (pid=6923) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 237
# (pid=6922) v_max: 4.04661795519353
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 239
# (pid=6919) v_max: 4.141741239205832
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 262
# (pid=6926) v_max: 5.234739483008334
# (pid=6926) -----------------------
# (pid=6920)  Retrying in 1 seconds
# (pid=6923)  Retrying in 1 seconds
# (pid=6919)  Retrying in 1 seconds
# (pid=6922)  Retrying in 1 seconds
# (pid=6926)  Retrying in 1 seconds
# (pid=6920) Could not connect to TraCI server at localhost:52815 [Errno 111] Connection refused
# (pid=6920)  Retrying in 2 seconds
# (pid=6923) Could not connect to TraCI server at localhost:41157 [Errno 111] Connection refused
# (pid=6923)  Retrying in 2 seconds
# (pid=6922) Could not connect to TraCI server at localhost:48847 [Errno 111] Connection refused
# ...
# (pid=6920) -----------------------
# (pid=6920) ring length: 229
# (pid=6920) v_max: 3.666034803266416
# (pid=6920) -----------------------
# (pid=6922)
# (pid=6922) -----------------------
# (pid=6922) ring length: 223
# (pid=6922) v_max: 3.3805185755587788
# (pid=6922) -----------------------
# (pid=6919)
# (pid=6919) -----------------------
# (pid=6919) ring length: 258
# (pid=6919) v_max: 5.044800727535787
# (pid=6919) -----------------------
# (pid=6926)
# (pid=6926) -----------------------
# (pid=6926) ring length: 230
# (pid=6926) v_max: 3.7136148111012934
# (pid=6926) -----------------------
# (pid=6923)
# (pid=6923) -----------------------
# (pid=6923) ring length: 234
# (pid=6923) v_max: 3.903915223349057
# (pid=6923) -----------------------
# (pid=6920)  Retrying in 1 seconds
# Result for PPO_WaveAttenuationPOEnv-v0_e93a5_00000:
#   agent_timesteps_total: 12000000
#   custom_metrics: {}
#   date: 2023-04-13_02-20-47
#   done: true
#   episode_len_mean: 3000.0
#   episode_media: {}
#   episode_reward_max: 8410.758322087617
#   episode_reward_mean: 3839.697076151588
#   episode_reward_min: 188.72091570331952
#   episodes_this_iter: 20
#   episodes_total: 4000
#   experiment_id: 4662df0f04464fe38c0c6093d67aa010
#   hostname: michael-lab
#   info:
#     learner:
#       default_policy:
#         custom_metrics: {}
#         learner_stats:
#           allreduce_latency: 0.0
#           cur_kl_coeff: 2.4892061111444565e-61
#           cur_lr: 5.000000000000001e-05
#           entropy: 0.5969273542353848
#           entropy_coeff: 0.0
#           kl: 0.0006782341526769117
#           policy_loss: -0.0002193191091714701
#           total_loss: 2006.4969950011036
#           vf_explained_var: 0.05935903266072273
#           vf_loss: 2006.4972158989165
#         model: {}
#     num_agent_steps_sampled: 12000000
#     num_steps_sampled: 12000000
#     num_steps_trained: 12000000
#   iterations_since_restore: 200
#   node_ip: 141.225.9.236
#   num_healthy_workers: 5
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 21.362585034013605
#     ram_util_percent: 25.661224489795917
#   pid: 6925
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.05507086113485121
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 3.2445705553506525
#     mean_inference_ms: 0.5306116722148091
#     mean_raw_obs_processing_ms: 3.9969413108236425
#   time_since_restore: 25659.61583995819
#   time_this_iter_s: 102.78470063209534
#   time_total_s: 25659.61583995819
#   timers:
#     learn_throughput: 7778.401
#     learn_time_ms: 7713.668
#     sample_throughput: 621.754
#     sample_time_ms: 96501.126
#     update_time_ms: 1.035
#   timestamp: 1681370447
#   timesteps_since_restore: 0
#   timesteps_total: 12000000
#   training_iteration: 200
#   trial_id: e93a5_00000
# (pid=6925) 2023-04-13 02:20:47,866	WARNING ppo.py:242 -- The magnitude of your environment rewards are more than 384.0x the scale of `vf_clip_param`. This means that it will take more than 384.0 iterations for your value function to converge. If this is not intended, consider increasing `vf_clip_param`.
# == Status ==<br>Memory usage on this node: 8.0/31.2 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 6.0/11 CPUs, 0/11 GPUs, 0.0/9.9 GiB heap, 0.0/14.65 GiB objects (0.0/1.0 CPU_group_4_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_5_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_2_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_1_27c74f409b0302333958eea1c16c481c, 0.0/1.0 accelerator_type:G, 0.0/1.0 CPU_group_3_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_0_27c74f409b0302333958eea1c16c481c, 0.0/6.0 CPU_group_27c74f409b0302333958eea1c16c481c)<br>Result logdir: /home/michael-lab/ray_results/singleagent_ring<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                             </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">      ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_e93a5_00000</td><td>RUNNING </td><td>141.225.9.236:6925</td><td style="text-align: right;">   200</td><td style="text-align: right;">         25659.6</td><td style="text-align: right;">12000000</td><td style="text-align: right;">  3839.7</td><td style="text-align: right;">             8410.76</td><td style="text-align: right;">             188.721</td><td style="text-align: right;">              3000</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Memory usage on this node: 8.0/31.2 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/11 CPUs, 0/11 GPUs, 0.0/9.9 GiB heap, 0.0/14.65 GiB objects (0.0/1.0 CPU_group_2_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_0_27c74f409b0302333958eea1c16c481c, 0.0/1.0 accelerator_type:G, 0.0/1.0 CPU_group_3_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_1_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_5_27c74f409b0302333958eea1c16c481c, 0.0/1.0 CPU_group_4_27c74f409b0302333958eea1c16c481c, 0.0/6.0 CPU_group_27c74f409b0302333958eea1c16c481c)<br>Result logdir: /home/michael-lab/ray_results/singleagent_ring<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                             </th><th>status    </th><th>loc  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">      ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_WaveAttenuationPOEnv-v0_e93a5_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">   200</td><td style="text-align: right;">         25659.6</td><td style="text-align: right;">12000000</td><td style="text-align: right;">  3839.7</td><td style="text-align: right;">             8410.76</td><td style="text-align: right;">             188.721</td><td style="text-align: right;">              3000</td></tr>
# </tbody>
# </table><br><br>
# (pid=6920) 2023-04-13 02:20:48,256	ERROR worker.py:421 -- SystemExit was raised from the worker
# (pid=6920) Traceback (most recent call last):
# (pid=6920)   File "python/ray/_raylet.pyx", line 530, in ray._raylet.execute_task
# (pid=6920)   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
# (pid=6920)   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task.function_executor
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=6920)     return method(__ray_actor, *args, **kwargs)
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/actor.py", line 1027, in __ray_terminate__
# (pid=6920)     ray.actor.exit_actor()
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/actor.py", line 1103, in exit_actor
# (pid=6920)     raise exit
# (pid=6920) SystemExit: 0
# (pid=6920)
# (pid=6920) During handling of the above exception, another exception occurred:
# (pid=6920)
# (pid=6920) Traceback (most recent call last):
# (pid=6920)   File "python/ray/_raylet.pyx", line 632, in ray._raylet.task_execution_handler
# (pid=6920)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task
# (pid=6920)   File "python/ray/_raylet.pyx", line 523, in ray._raylet.execute_task
# (pid=6920)   File "python/ray/includes/libcoreworker.pxi", line 33, in ray._raylet.ProfileEvent.__exit__
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 167, in format_exc
# (pid=6920)     return "".join(format_exception(*sys.exc_info(), limit=limit, chain=chain))
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 121, in format_exception
# (pid=6920)     type(value), value, tb, limit=limit).format(chain=chain))
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 508, in __init__
# (pid=6920)     capture_locals=capture_locals)
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 363, in extract
# (pid=6920)     f.line
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 285, in line
# (pid=6920)     self._line = linecache.getline(self.filename, self.lineno).strip()
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/linecache.py", line 16, in getline
# (pid=6920)     lines = getlines(filename, module_globals)
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/linecache.py", line 47, in getlines
# (pid=6920)     return updatecache(filename, module_globals)
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/linecache.py", line 137, in updatecache
# (pid=6920)     lines = fp.readlines()
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/codecs.py", line 319, in decode
# (pid=6920)     def decode(self, input, final=False):
# (pid=6920)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 418, in sigterm_handler
# (pid=6920)     sys.exit(1)
# (pid=6920) SystemExit: 1
# (pid=6926) 2023-04-13 02:20:48,254	ERROR worker.py:421 -- SystemExit was raised from the worker
# (pid=6926) Traceback (most recent call last):
# (pid=6926)   File "python/ray/_raylet.pyx", line 523, in ray._raylet.execute_task
# (pid=6926)   File "python/ray/_raylet.pyx", line 530, in ray._raylet.execute_task
# (pid=6926)   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
# (pid=6926)   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task.function_executor
# (pid=6926)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=6926)     return method(__ray_actor, *args, **kwargs)
# (pid=6926)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/actor.py", line 1027, in __ray_terminate__
# (pid=6926)     ray.actor.exit_actor()
# (pid=6926)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/actor.py", line 1103, in exit_actor
# (pid=6926)     raise exit
# (pid=6926) SystemExit: 0
# (pid=6926)
# (pid=6926) During handling of the above exception, another exception occurred:
# (pid=6926)
# (pid=6926) Traceback (most recent call last):
# (pid=6926)   File "python/ray/_raylet.pyx", line 632, in ray._raylet.task_execution_handler
# (pid=6926)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task
# (pid=6926)   File "python/ray/includes/libcoreworker.pxi", line 33, in ray._raylet.ProfileEvent.__exit__
# (pid=6926)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 167, in format_exc
# (pid=6926)     return "".join(format_exception(*sys.exc_info(), limit=limit, chain=chain))
# (pid=6926)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 121, in format_exception
# (pid=6926)     type(value), value, tb, limit=limit).format(chain=chain))
# (pid=6926)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 508, in __init__
# (pid=6926)     capture_locals=capture_locals)
# (pid=6926)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 349, in extract
# (pid=6926)     fnames.add(filename)
# (pid=6926)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 418, in sigterm_handler
# (pid=6926)     sys.exit(1)
# (pid=6926) SystemExit: 1
# (pid=6922) 2023-04-13 02:20:48,255	ERROR worker.py:421 -- SystemExit was raised from the worker
# (pid=6922) Traceback (most recent call last):
# (pid=6922)   File "python/ray/_raylet.pyx", line 530, in ray._raylet.execute_task
# (pid=6922)   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
# (pid=6922)   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task.function_executor
# (pid=6922)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=6922)     return method(__ray_actor, *args, **kwargs)
# (pid=6922)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/actor.py", line 1027, in __ray_terminate__
# (pid=6922)     ray.actor.exit_actor()
# (pid=6922)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/actor.py", line 1103, in exit_actor
# (pid=6922)     raise exit
# (pid=6922) SystemExit: 0
# (pid=6922)
# (pid=6922) During handling of the above exception, another exception occurred:
# (pid=6922)
# (pid=6922) Traceback (most recent call last):
# (pid=6922)   File "python/ray/_raylet.pyx", line 632, in ray._raylet.task_execution_handler
# (pid=6922)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task
# (pid=6922)   File "python/ray/_raylet.pyx", line 523, in ray._raylet.execute_task
# (pid=6922)   File "python/ray/includes/libcoreworker.pxi", line 33, in ray._raylet.ProfileEvent.__exit__
# (pid=6922)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 167, in format_exc
# (pid=6922)     return "".join(format_exception(*sys.exc_info(), limit=limit, chain=chain))
# (pid=6922)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 418, in sigterm_handler
# (pid=6922)     sys.exit(1)
# (pid=6922) SystemExit: 1
# (pid=6923) 2023-04-13 02:20:48,255	ERROR worker.py:421 -- SystemExit was raised from the worker
# (pid=6923) Traceback (most recent call last):
# (pid=6923)   File "python/ray/_raylet.pyx", line 530, in ray._raylet.execute_task
# (pid=6923)   File "python/ray/_raylet.pyx", line 534, in ray._raylet.execute_task
# (pid=6923)   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task.function_executor
# (pid=6923)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/_private/function_manager.py", line 563, in actor_method_executor
# (pid=6923)     return method(__ray_actor, *args, **kwargs)
# (pid=6923)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/actor.py", line 1027, in __ray_terminate__
# (pid=6923)     ray.actor.exit_actor()
# (pid=6923)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/actor.py", line 1103, in exit_actor
# (pid=6923)     raise exit
# (pid=6923) SystemExit: 0
# (pid=6923)
# (pid=6923) During handling of the above exception, another exception occurred:
# (pid=6923)
# (pid=6923) Traceback (most recent call last):
# (pid=6923)   File "python/ray/_raylet.pyx", line 632, in ray._raylet.task_execution_handler
# (pid=6923)   File "python/ray/_raylet.pyx", line 486, in ray._raylet.execute_task
# (pid=6923)   File "python/ray/_raylet.pyx", line 523, in ray._raylet.execute_task
# (pid=6923)   File "python/ray/includes/libcoreworker.pxi", line 33, in ray._raylet.ProfileEvent.__exit__
# (pid=6923)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 167, in format_exc
# (pid=6923)     return "".join(format_exception(*sys.exc_info(), limit=limit, chain=chain))
# (pid=6923)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 121, in format_exception
# (pid=6923)     type(value), value, tb, limit=limit).format(chain=chain))
# (pid=6923)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/traceback.py", line 509, in __init__
# (pid=6923)     self.exc_type = exc_type
# (pid=6923)   File "/home/michael-lab/miniconda3/envs/flow/lib/python3.7/site-packages/ray/worker.py", line 418, in sigterm_handler
# (pid=6923)     sys.exit(1)
# (pid=6923) SystemExit: 1
# 2023-04-13 02:20:48,363	INFO tune.py:550 -- Total run time: 25684.89 seconds (25684.52 seconds for the tuning loop).

# %% [markdown]
# ## Training Multiagent Ring Road

# %%
# %run ../../examples/train.py multiagent_ring

# %% [markdown]
# ## Training Single Agent Figure 8

# %%
# %run ../../examples/train.py singleagent_figure_eight

# %% [markdown]
# ## Training Intersection Network

# %%
# %run ../../examples/train.py intersection

# %% [markdown]
# ## Training Bottleneck

# %%
# %run ../../examples/train.py bottleneck0

# %% [markdown]
# ## Training Merge Network

# %%
# %run ../../examples/train.py merge0
