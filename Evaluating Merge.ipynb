# %%
# !python flow/visualize/visualizer_rllib.py\
/home/michael/ray_results/merge_0/PPO_MergePOEnv-v0_d65dd_00000_0_2022-10-09_17-43-47/ 190\
--num_rollouts 10
# Out:
# 2022-10-21 12:42:50,219	INFO services.py:1247 -- View the Ray dashboard at http://127.0.0.1:8265
# 2022-10-21 12:42:50,777	WARNING ppo.py:143 -- `train_batch_size` (3750) cannot be achieved with your other settings (num_workers=0 num_envs_per_worker=1 rollout_fragment_length=200)! Auto-adjusting `rollout_fragment_length` to 3750.
# 2022-10-21 12:42:50,777	INFO trainer.py:720 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2022-10-21 12:42:50,882	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:42:51,906	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# 2022-10-21 12:42:51,925	INFO trainable.py:383 -- Restored on 192.168.1.65 from checkpoint: /home/michael/ray_results/merge_0/PPO_MergePOEnv-v0_d65dd_00000_0_2022-10-09_17-43-47/checkpoint_190/checkpoint-190
# 2022-10-21 12:42:51,925	INFO trainable.py:390 -- Current state after restoring: {'_iteration': 190, '_timesteps_total': None, '_time_total': 2563.3705627918243, '_episodes_total': 950}
# 2022-10-21 12:42:52,614	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:42:54,132	WARNING deprecation.py:34 -- DeprecationWarning: `compute_action` has been deprecated. Use `compute_single_action` instead. This will raise an error in the future!
# 2022-10-21 12:42:54,369	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:42:56,141	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:42:57,913	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# Round 0, Return: 491.2570089110408
# (raylet) Traceback (most recent call last):
# 2022-10-21 12:42:59,663	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:43:01,458	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:43:03,231	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# Round 1, Return: 460.26300459658864
# 2022-10-21 12:43:05,011	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:43:06,798	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# ...
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:43:52,994	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# 2022-10-21 12:43:54,761	WARNING worker.py:1189 -- The agent on node michael-villarreal failed with the following error:
# Traceback (most recent call last):
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
#     loop.run_until_complete(agent.run())
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
#     modules = self._load_modules()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
#     c = cls(self)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
#     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
#     namespace="ray", port=metrics_export_port)))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
#     options=option, gatherer=option.registry, collector=collector)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
#     self.serve_http()
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
#     port=self.options.port, addr=str(self.options.address))
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
#     TmpServer.address_family, addr = _get_best_family(addr, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
#     infos = socket.getaddrinfo(address, port)
#   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
#
# (raylet) Traceback (most recent call last):
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 366, in <module>
# (raylet)     raise e
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 354, in <module>
# (raylet)     loop.run_until_complete(agent.run())
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
# (raylet)     return future.result()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 144, in run
# (raylet)     modules = self._load_modules()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/agent.py", line 98, in _load_modules
# (raylet)     c = cls(self)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/new_dashboard/modules/reporter/reporter_agent.py", line 148, in __init__
# (raylet)     self._metrics_agent = MetricsAgent(dashboard_agent.metrics_export_port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/metrics_agent.py", line 77, in __init__
# (raylet)     namespace="ray", port=metrics_export_port)))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 334, in new_stats_exporter
# (raylet)     options=option, gatherer=option.registry, collector=collector)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 266, in __init__
# (raylet)     self.serve_http()
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/ray/_private/prometheus_exporter.py", line 321, in serve_http
# (raylet)     port=self.options.port, addr=str(self.options.address))
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 168, in start_wsgi_server
# (raylet)     TmpServer.address_family, addr = _get_best_family(addr, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/site-packages/prometheus_client/exposition.py", line 157, in _get_best_family
# (raylet)     infos = socket.getaddrinfo(address, port)
# (raylet)   File "/home/michael/anaconda3/envs/flow/lib/python3.7/socket.py", line 748, in getaddrinfo
# (raylet)     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# (raylet) socket.gaierror: [Errno -2] Name or service not known
# Round 9, Return: 461.711502684263
# ==== Summary of results ====
# Return:
# [14.957343645635124, 14.098427185957911, 14.593264397338372, 16.006004233183457, 13.637797206771662, 14.596435542306105, 15.717594498038395, 13.998031272164905, 10.523966409715543, 14.177857177107677]
# [491.2570089110408, 460.26300459658864, 481.3846600004506, 522.245633026859, 450.6712425545881, 480.26856351924323, 511.9897176783924, 462.9991306487564, 339.63928727131054, 461.711502684263]
# Average, std: 466.24297508914924, 47.55895418701628
#
# Speed, mean (m/s):
# [14.957343645635124, 14.098427185957911, 14.593264397338372, 16.006004233183457, 13.637797206771662, 14.596435542306105, 15.717594498038395, 13.998031272164905, 10.523966409715543, 14.177857177107677]
# Average, std: 14.230672156821916, 1.4255391123188454
#
# Speed, std (m/s):
# [1.9235830791524038, 3.470837061500399, 2.5212337399559717, 2.037351068438726, 3.0473880366345782, 3.5552774604201036, 1.3908648959493979, 3.304199911157275, 4.733240855992276, 3.3698902533216772]
# Average, std: 2.935386636252281, 0.9288647303509772
#
# Outflows (veh/hr):
# [2030.4, 1879.2, 2016.0, 1987.2, 1879.2, 1742.4, 2052.0, 1886.4, 1396.8, 2037.6]
# Average, std: 1890.7199999999998, 189.2983930201205
# Inflows (veh/hr):
# [2102.4, 2102.4, 2102.4, 2102.4, 2102.4, 2102.4, 2102.4, 2102.4, 2102.4, 2102.4]
# Average, std: 2102.4000000000005, 4.547473508864641e-13
# Throughput efficiency (veh/hr):
# [0.9657534246575342, 0.8938356164383562, 0.958904109589041, 0.9452054794520548, 0.8938356164383562, 0.8287671232876712, 0.9760273972602739, 0.8972602739726028, 0.6643835616438356, 0.9691780821917807]
# Average, std: 0.8993150684931507, 0.090039189982934

# %% [markdown]
# ### Trial Results Directory Name

# %%
results_dir_name = "trial_results"

# %% [markdown]
# ## Mean Over Rollout

# %%
import numpy as np

mean_collector = []

with open(f"./michael_files/{results_dir_name}/avg_velocity.txt", "r+") as f:
    for line in f:
        data = line.split(",")
        data = data[:len(data)-1]
        data = np.asarray([float(i) for i in data])
        mean_vehs = np.mean(data)
        mean_collector.append(mean_vehs)
        print(f"Mean Velocity Over Rollout: {mean_vehs}")
        with open(f"./michael_files/{results_dir_name}/mean_rollout_velocity.txt", "a") as g:
            g.write(f"Mean Velocity Over Rollout: {mean_vehs}\n")

with open(f"./michael_files/{results_dir_name}/mean_rollout_velocity.txt", "a") as g:
    mean_rollout = np.mean(mean_collector)
    std_rollout = np.std(mean_collector)
    var_rollout = np.var(mean_collector)
    
    g.write(f"Mean of Rollouts: {mean_rollout}\n")
    g.write(f"Std of Rollouts: {std_rollout}\n")
    g.write(f"Variance of Rollouts: {var_rollout}\n")
    
    print(f"Mean of Rollouts: {mean_rollout}\n")
    print(f"Std of Rollouts: {std_rollout}\n")
    print(f"Variance of Rollouts: {var_rollout}\n")
# Out:
# Mean Velocity Over Rollout: 14.579923928588817
# Mean Velocity Over Rollout: 14.50230883082635
# Mean Velocity Over Rollout: 14.758384332514643
# Mean Velocity Over Rollout: 16.506962246897224
# Mean Velocity Over Rollout: 13.339789974530047
# Mean Velocity Over Rollout: 14.861834996798983
# Mean Velocity Over Rollout: 15.260597737596894
# Mean Velocity Over Rollout: 14.973473388424548
# Mean Velocity Over Rollout: 12.781417656889454
# Mean Velocity Over Rollout: 13.111089739064239
# Mean of Rollouts: 14.467578283213118
#
# Std of Rollouts: 1.0607938645516284
#
# Variance of Rollouts: 1.1252836230703784

# %% [markdown]
# ## Mean and Min for Last 100 Seconds

# %%
import numpy as np

mean_collector = []

with open(f"./michael_files/{results_dir_name}/avg_velocity.txt", "r+") as f:
    for line in f:
        data = line.split(",")
        data = data[:len(data)-1]
        data = np.asarray([float(i) for i in data])
        mean_last_100_seconds = np.mean(data[-1000:])
        mean_collector.append(mean_last_100_seconds)
        print(f"Mean Last 100 Seconds: {mean_last_100_seconds}")
        with open(f"./michael_files/{results_dir_name}/last_100_seconds.txt", "a") as g:
            g.write(f"Mean Last 100 Seconds: {mean_last_100_seconds}\n")

print(f"Mean of last 100 secs over rollouts: {np.mean(mean_collector)}")

with open(f"./michael_files/{results_dir_name}/last_100_seconds.txt", "a") as g:
    g.write(f"Mean of last 100 secs over rollouts: {np.mean(mean_collector)}\n")
    
    std_100 = np.std(mean_collector)
    var_100 = np.var(mean_collector)
    
    g.write(f"Std of last 100 secs over rollouts: {std_100}\n")
    g.write(f"Variance of last 100 secs over rollouts: {var_100}\n")
# Out:
# Mean Last 100 Seconds: 14.579923928588817
# Mean Last 100 Seconds: 14.50230883082635
# Mean Last 100 Seconds: 14.758384332514643
# Mean Last 100 Seconds: 16.506962246897224
# Mean Last 100 Seconds: 13.339789974530047
# Mean Last 100 Seconds: 14.861834996798983
# Mean Last 100 Seconds: 15.260597737596894
# Mean Last 100 Seconds: 14.973473388424548
# Mean Last 100 Seconds: 12.781417656889454
# Mean Last 100 Seconds: 13.111089739064239
# Mean of last 100 secs over rollouts: 14.467578283213118

# %%
import numpy as np

with open(f"./michael_files/{results_dir_name}/min_velocity.txt", "r+") as f:
    for line in f:
        data = line.split(",")
        data = data[:len(data)-1]
        data = np.asarray([float(i) for i in data])
        min_last_100_seconds = np.min(data[-1000:])
        print(f"Min Last 100 Seconds: {min_last_100_seconds}")
        with open(f"./michael_files/{results_dir_name}/last_100_seconds.txt", "a") as g:
            g.write(f"Min Last 100 Seconds: {min_last_100_seconds}\n")
# Out:
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0
# Min Last 100 Seconds: 0.0

# %% [markdown]
# ## Charting Avg. Velocity for All Vehicles

# %%
import numpy as np
import matplotlib.pyplot as plt

with open(f"./michael_files/{results_dir_name}/avg_velocity.txt", "r+") as f:
    count = 0
    for line in f:
        data = line.split(",")
        data = data[:len(data)-1]
        data = np.asarray([float(i) for i in data])

        fig, ax = plt.subplots(figsize=(8,8), dpi=100)
        xticks = np.arange(0,len(data)+1,500)
        ax.set_ylabel("Avg. Velocity")
        ax.set_xlabel("Timesteps")
        ax.plot(data)
        ax.set_xticks(xticks) 
        fig.savefig(f"./michael_files/{results_dir_name}/avg_velocity{count}.png")
        
        count += 1

# %% [markdown]
# ## Charting RL Velocity

# %%
import numpy as np
import matplotlib.pyplot as plt

with open(f"./michael_files/{results_dir_name}/rl_velocity.txt", "r+") as f:
    count = 0
    for line in f:
        data = line.split(",")
        data = data[:len(data)-1]
        data = np.asarray([float(i) for i in data])

        fig, ax = plt.subplots(figsize=(8,8), dpi=100)
        xticks = np.arange(0,len(data)+1,500)
        ax.set_ylabel("RL Velocity")
        ax.set_xlabel("Timesteps")
        ax.plot(data)
        ax.set_xticks(xticks) 
        fig.savefig(f"./michael_files/{results_dir_name}/rl_velocity{count}.png")
        
        count += 1

# %% [markdown]
# ## Charting RL Realized Acceleration

# %%
import numpy as np
import matplotlib.pyplot as plt

with open(f"./michael_files/{results_dir_name}/rl_accel_realized.txt", "r+") as f:
    count = 0
    for line in f:
        data = line.split(",")
        data = data[:len(data)-1]
        data = np.asarray([float(i) for i in data])

        fig, ax = plt.subplots(figsize=(8,8), dpi=100)
        xticks = np.arange(0,len(data)+1,500)
        ax.set_ylabel("RL Accel. Realized")
        ax.set_xlabel("Timesteps")
        ax.plot(data)
        ax.set_xticks(xticks) 
        fig.savefig(f"./michael_files/{results_dir_name}/rl_accel_realized{count}.png")
        
        count += 1
